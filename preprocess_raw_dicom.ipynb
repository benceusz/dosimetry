# %%
import pydicom as dicom
import os
import shutil
import numpy as np

# %%
project_dir = "/media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split"
output_dir = "/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split"

list_studies = [ name for name in os.listdir(project_dir) if os.path.isdir(os.path.join(project_dir, name))  ]

# %%
if not os.path.isdir(output_dir):
    os.mkdir(output_dir)

# %%
# functions 

def copy_dcm_file(source, destination):
    """
    Source path
    Destination path: destination
    """
    try:
        shutil.copyfile(source, destination)
        #print("File copied successfully.")

    # If source and destination are same
    except shutil.SameFileError:
        print("Source and destination represents the same file.")

    # If destination is a directory.
    except IsADirectoryError:
        print("Destination is a directory: %s" %destination)

    # If there is any permission issue
    except PermissionError:
        print("Permission denied.")

    # For other errors
    except:
        print("Error occurred while copying file.")
    return

# %%
path_out_patient
# Out:
# '/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split/100'

# %%
for i_dir in list_studies:
    #i_dir = "10"

    path_out_patient = os.path.join(output_dir, i_dir)
    path_in_patient = os.path.join(project_dir, i_dir)

    if os.path.isdir(path_out_patient):
        print("patient %s exist"%i_dir)
        continue
    else:
        os.mkdir(path_out_patient)
        
    
    print("processing study: %s" % i_dir)
    if not os.path.isdir(os.path.join(path_out_patient,"33")): os.mkdir(os.path.join(path_out_patient,"33"))
    if not os.path.isdir(os.path.join(path_out_patient,"66")): os.mkdir(os.path.join(path_out_patient,"66"))
    if not os.path.isdir(os.path.join(path_out_patient,"100")): os.mkdir(os.path.join(path_out_patient,"100"))

    print(path_in_patient)
    counter = 0
    c_failure = 0

    max_slice_33 = 0
    max_series33 = []
    max_slice_66 = 0
    max_series66 = []
    max_slice_100 = 0
    max_series100 = []


    for root, dir, files in os.walk(path_in_patient):
        for i_file in files:
            path_i_file = os.path.join(path_in_patient, i_file)
            ds = dicom.read_file(path_i_file)
            try:
                if ds.ImageType[6] == "DET_A" and ds.ImageType[0] == "ORIGINAL":
                    path_det_a = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber), i_file)
                    if ds.InstanceNumber >= max_slice_66: max_slice_66 = ds.InstanceNumber

                elif ds.ImageType[6] == "DET_B" and ds.ImageType[0] == "ORIGINAL":
                    path_det_b = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber), i_file)
                    if ds.InstanceNumber >= max_slice_33: max_slice_33 = ds.InstanceNumber 

                elif ds.ImageType[6] == "DET_AB" and ds.ImageType[0] == "ORIGINAL":
                    path_det_ab = os.path.join(output_dir, i_dir, "100",str(ds.SeriesNumber), i_file)
                    if ds.InstanceNumber >= max_slice_100: max_slice_100 = ds.InstanceNumber 
            except:
                pass
    
    print(max_slice_33)
    print(max_slice_66)
    print(max_series100)
    
    if len({max_slice_33, max_slice_66, max_slice_100}) != 1:
        min_slice_threshold = min(max_slice_33, max_slice_66, max_slice_100)
        if max_slice_33 != min_slice_threshold:       
            max_slice_33 = min_slice_threshold
            print("WARNING! The filter of the sequence at patient %s, in dose 33 has been lowered"%i_dir)
        if max_slice_66 != min_slice_threshold:       
            max_slice_66 = min_slice_threshold
            print("WARNING! The filter of the sequence at patient %s, in dose 66 has been lowered"%i_dir)
        if max_slice_100 != min_slice_threshold:       
            max_slice_100 = min_slice_threshold
            print("WARNING! The filter of the sequence at patient %s, in dose 100 has been lowered"%i_dir)
                
    print("Sequences before")
    print(max_series33)
    print(max_series66)
    print(max_series100)
            
    # find the sequences in each subfolder that has the biggest number of slices
    for root, dir, files in os.walk(path_in_patient):
        for i_file in files:
            path_i_file = os.path.join(path_in_patient, i_file)
            ds = dicom.read_file(path_i_file)
            
            if len({max_slice_33, max_slice_66, max_slice_100}) == 1:
                try:
                    if ds.ImageType[6] == "DET_A" and ds.ImageType[0] == "ORIGINAL":
                        path_det_a = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber), i_file)
                        if ds.InstanceNumber == max_slice_66: 
                            if ds.SeriesNumber not in max_series66: max_series66+= [ds.SeriesNumber ] 
                        if ds.InstanceNumber > min_slice_threshold: 
                            if ds.SeriesNumber in max_series66: max_series66.remove(ds.SeriesNumber)  

                    elif ds.ImageType[6] == "DET_B" and ds.ImageType[0] == "ORIGINAL":
                        path_det_b = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber), i_file)
                        if ds.InstanceNumber == max_slice_33: 
                            if ds.SeriesNumber not in max_series33: max_series33+= [ds.SeriesNumber ] 
                        if ds.InstanceNumber > min_slice_threshold: 
                            if ds.SeriesNumber in max_series33: max_series33.remove(ds.SeriesNumber)    

                    elif ds.ImageType[6] == "DET_AB" and ds.ImageType[0] == "ORIGINAL":
                        path_det_ab = os.path.join(output_dir, i_dir, "100",str(ds.SeriesNumber), i_file)
                        if ds.InstanceNumber == max_slice_100: 
                            if ds.SeriesNumber not in max_series100: max_series100+= [ds.SeriesNumber ]
                        if ds.InstanceNumber > min_slice_threshold: 
                            if ds.SeriesNumber in max_series100: max_series100.remove(ds.SeriesNumber)
                except:
                        pass
            else:
                print("WARNING! Sequence with max slice are not present in all the subfolder at patient %s!" % i_dir)

                
    print("Sequences after")
    print(max_series33)
    print(max_series66)
    print(max_series100)


    if len({max_slice_33, max_slice_66, max_slice_100}) == 1:
        # delete the series that have not the same number of slices as max and not the same as in other subfolders (33,66,100)
        for root, dir, files in os.walk(path_in_patient):
            for i_file in files:
                path_i_file = os.path.join(path_in_patient, i_file)
                ds = dicom.read_file(path_i_file)
                #print(os.path.join(path_in_patient, i_file))
                try:
                    if ds.ImageType[6] == "DET_A" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series66 :
                        path_det_a = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber), i_file)
                        seq_dir = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber))
                        if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
                        if not os.path.isfile(path_det_a): copy_dcm_file(source = path_i_file, destination = path_det_a)

                    elif ds.ImageType[6] == "DET_B" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series33:
                        path_det_b = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber), i_file)
                        seq_dir = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber))
                        if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
                        if not os.path.isfile(path_det_b): copy_dcm_file(source = path_i_file, destination = path_det_b)

                    elif ds.ImageType[6] == "DET_AB" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series100:
                        seq_dir = os.path.join(output_dir, i_dir, "100", str(ds.SeriesNumber))
                        if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
                        path_det_ab = os.path.join(output_dir, i_dir, "100",str(ds.SeriesNumber), i_file)
                        if not os.path.isfile(path_det_ab): copy_dcm_file(source = path_i_file, destination = path_det_ab)
                    else:
                        counter +=1
                except:
                    c_failure += 1
                    print("Failure B")
                    #print("'FileDataset' %s could not be processed.  has it no attribute 'ImageType'? " % i_file)
    else:
        for root, dir, files in os.walk(path_in_patient):
            for i_file in files:
                path_i_file = os.path.join(path_in_patient, i_file)
                ds = dicom.read_file(path_i_file)
                #print(os.path.join(path_in_patient, i_file))
                try:
                    if ds.ImageType[6] == "DET_A" and ds.ImageType[0] == "ORIGINAL":
                        path_det_a = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber), i_file)
                        seq_dir = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber))
                        if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
                        if not os.path.isfile(path_det_a): copy_dcm_file(source = path_i_file, destination = path_det_a)

                    elif ds.ImageType[6] == "DET_B" and ds.ImageType[0] == "ORIGINAL":
                        path_det_b = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber), i_file)
                        seq_dir = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber))
                        if not os.path.isdir(seq_dir): os.mkdir(seq_dir)                    
                        if not os.path.isfile(path_det_b): copy_dcm_file(source = path_i_file, destination = path_det_b)

                    elif ds.ImageType[6] == "DET_AB" and ds.ImageType[0] == "ORIGINAL":
                        path_det_ab = os.path.join(output_dir, i_dir, "100",str(ds.SeriesNumber), i_file)
                        seq_dir = os.path.join(output_dir, i_dir, "100", str(ds.SeriesNumber))
                        if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
                        if not os.path.isfile(path_det_ab): copy_dcm_file(source = path_i_file, destination = path_det_ab)
                    else:
                        counter +=1
                except:
                    c_failure += 1
                    #print("'FileDataset' %s could not be processed.  has it no attribute 'ImageType'? " % i_file)


    print("number of files that has not bee copied: %i" % counter)
    print("number of failures occured during processing.E.g. file does not have metaheader: %i" % c_failure)
# Out:
# patient 1 exist
# patient 10 exist
# patient 100 exist
# patient 101 exist
# patient 102 exist
# patient 103 exist
# patient 104 exist
# patient 105 exist
# patient 106 exist
# patient 107 exist
# patient 108 exist
# processing study: 109
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/109
# 336
# 336
# []
# WARNING! The filter of the sequence at patient 109, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["9"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 717
# number of failures occured during processing.E.g. file does not have metaheader: 9
# patient 11 exist
# processing study: 110
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/110
# 321
# 321
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 167
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 111
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/111
# 400
# 400
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1973
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 112
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/112
# 286
# 286
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["9"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 584
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 113
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/113
# 348
# 348
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1771
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 114
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/114
# 315
# 315
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 150
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 115
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/115
# 294
# 294
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 141
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 116
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/116
# 307
# 307
# []
# WARNING! The filter of the sequence at patient 116, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 502
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 117
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/117
# 326
# 326
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1463
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 118
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/118
# 336
# 336
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1708
# number of failures occured during processing.E.g. file does not have metaheader: 10
# processing study: 30
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/30
# 322
# 322
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1288
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 31
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/31
# 317
# 317
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1320
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 32
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/32
# 335
# 335
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 3015
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 33
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/33
# 307
# 307
# []
# WARNING! The filter of the sequence at patient 33, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# number of files that has not bee copied: 331
# number of failures occured during processing.E.g. file does not have metaheader: 2
# processing study: 34
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/34
# 286
# 286
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7", "11"]
# ["6", "10"]
# ["5", "8", "12"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 676
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 35
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/35
# 333
# 333
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1880
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 36
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/36
# 316
# 316
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1336
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 37
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/37
# 307
# 307
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 0
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 38
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/38
# 333
# 333
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# number of files that has not bee copied: 1363
# number of failures occured during processing.E.g. file does not have metaheader: 2
# processing study: 39
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/39
# 345
# 345
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1536
# number of failures occured during processing.E.g. file does not have metaheader: 5
# processing study: 4
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/4
# 356
# 356
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1785
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 40
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/40
# 319
# 319
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1445
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 41
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/41
# 289
# 289
# []
# WARNING! The filter of the sequence at patient 41, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 456
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 42
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/42
# 329
# 329
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1477
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 43
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/43
# 330
# 330
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1480
# number of failures occured during processing.E.g. file does not have metaheader: 5
# processing study: 44
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/44
# 330
# 330
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1481
# number of failures occured during processing.E.g. file does not have metaheader: 5
# processing study: 45
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/45
# 296
# 296
# []
# WARNING! The filter of the sequence at patient 45, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["8"]
# ["7"]
# ["9"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 892
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 46
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/46
# 326
# 326
# []
# WARNING! The filter of the sequence at patient 46, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 518
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 47
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/47
# 324
# 324
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 0
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 48
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/48
# 323
# 323
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 152
# number of failures occured during processing.E.g. file does not have metaheader: 5
# processing study: 49
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/49
# 294
# 294
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 70
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 5
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/5
# 328
# 328
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1644
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 51
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/51
# 304
# 304
# []
# WARNING! The filter of the sequence at patient 51, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 441
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 52
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/52
# 330
# 330
# []
# WARNING! The filter of the sequence at patient 52, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 511
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 53
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/53
# 374
# 374
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1496
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 54
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/54
# 298
# 298
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["9"]
# Failure B
# Failure B
# number of files that has not bee copied: 187
# number of failures occured during processing.E.g. file does not have metaheader: 2
# processing study: 55
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/55
# 348
# 348
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1720
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 56
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/56
# 364
# 364
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1629
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 57
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/57
# 333
# 333
# []
# WARNING! The filter of the sequence at patient 57, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 515
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 58
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/58
# 391
# 391
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1930
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 59
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/59
# 307
# 307
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 648
# number of failures occured during processing.E.g. file does not have metaheader: 10
# processing study: 6
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/6
# 339
# 339
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1706
# number of failures occured during processing.E.g. file does not have metaheader: 10
# processing study: 60
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/60
# 316
# 316
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["9"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 711
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 61
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/61
# 323
# 323
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 60
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 62
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/62
# 337
# 337
# []
# WARNING! The filter of the sequence at patient 62, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 525
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 63
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/63
# 331
# 331
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 639
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 64
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/64
# 326
# 326
# []
# WARNING! The filter of the sequence at patient 64, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1015
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 65
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/65
# 328
# 328
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1476
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 66
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/66
# 296
# 296
# []
# WARNING! The filter of the sequence at patient 66, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 444
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 67
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/67
# 305
# 305
# []
# WARNING! The filter of the sequence at patient 67, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 477
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 68
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/68
# 343
# 343
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1528
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 69
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/69
# 296
# 296
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 174
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 7
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/7
# 299
# 299
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 643
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 70
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/70
# 283
# 283
# []
# WARNING! The filter of the sequence at patient 70, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 434
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 72
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/72
# 316
# 316
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1533
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 73
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/73
# 330
# 330
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1644
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 74
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/74
# 365
# 365
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1796
# number of failures occured during processing.E.g. file does not have metaheader: 16
# processing study: 75
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/75
# 339
# 339
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1536
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 76
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/76
# 329
# 329
# []
# WARNING! The filter of the sequence at patient 76, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 513
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 77
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/77
# 295
# 295
# []
# WARNING! The filter of the sequence at patient 77, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 130
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 78
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/78
# 341
# 341
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1522
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 79
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/79
# 290
# 290
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 153
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 8
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/8
# 388
# 388
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 2110
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 80
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/80
# 361
# 361
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1836
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 81
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/81
# 249
# 249
# []
# WARNING! The filter of the sequence at patient 81, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 415
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 82
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/82
# 290
# 290
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1308
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 83
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/83
# 335
# 335
# []
# WARNING! The filter of the sequence at patient 83, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 552
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 84
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/84
# 274
# 274
# []
# WARNING! The filter of the sequence at patient 84, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 422
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 85
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/85
# 351
# 351
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1745
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 86
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/86
# 351
# 351
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1570
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 87
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/87
# 310
# 310
# []
# WARNING! The filter of the sequence at patient 87, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 486
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 88
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/88
# 331
# 331
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1475
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 89
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/89
# 289
# 289
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 592
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 9
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/9
# 358
# 358
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 3335
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 90
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/90
# 292
# 292
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["9"]
# ["8"]
# ["10"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 586
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 91
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/91
# 292
# 292
# []
# WARNING! The filter of the sequence at patient 91, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 462
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 92
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/92
# 304
# 304
# []
# WARNING! The filter of the sequence at patient 92, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 463
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 93
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/93
# 328
# 328
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1612
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 94
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/94
# 343
# 343
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1730
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 95
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/95
# 328
# 328
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1647
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 96
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/96
# 337
# 337
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1659
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 97
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/97
# 346
# 346
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1568
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 98
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/98
# 335
# 335
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1483
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 99
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/99
# 330
# 330
# []
# WARNING! The filter of the sequence at patient 99, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 519
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 12
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/12
# 352
# 352
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1715
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 120
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/120
# 281
# 281
# []
# WARNING! The filter of the sequence at patient 120, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 497
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 121
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/121
# 284
# 284
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1465
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 122
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/122
# 291
# 291
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1523
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 123
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/123
# 304
# 304
# []
# WARNING! The filter of the sequence at patient 123, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 467
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 124
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/124
# 304
# 304
# []
# WARNING! The filter of the sequence at patient 124, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 486
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 125
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/125
# 289
# 289
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 589
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 126
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/126
# 335
# 335
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1497
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 127
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/127
# 331
# 331
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1645
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 128
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/128
# 351
# 351
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1750
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 129
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/129
# 410
# 410
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 2044
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 13
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/13
# 311
# 311
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1482
# number of failures occured during processing.E.g. file does not have metaheader: 100
# processing study: 130
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/130
# 326
# 326
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1640
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 131
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/131
# 284
# 284
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 569
# number of failures occured during processing.E.g. file does not have metaheader: 9
# processing study: 132
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/132
# 295
# 295
# []
# WARNING! The filter of the sequence at patient 132, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 480
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 133
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/133
# 352
# 352
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1764
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 134
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/134
# 320
# 320
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1614
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 135
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/135
# 288
# 288
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["8"]
# ["7"]
# ["9"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 596
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 136
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/136
# 308
# 308
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1521
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 137
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/137
# 397
# 397
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1933
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 138
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/138
# 288
# 288
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["11"]
# ["10"]
# ["12"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 616
# number of failures occured during processing.E.g. file does not have metaheader: 10
# processing study: 139
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/139
# 295
# 295
# []
# WARNING! The filter of the sequence at patient 139, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 457
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 119
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/119
# 325
# 325
# []
# WARNING! The filter of the sequence at patient 119, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 504
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 14
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/14
# 347
# 347
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 2177
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 160
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/160
# 268
# 268
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 585
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 181
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/181
# 305
# 305
# []
# WARNING! The filter of the sequence at patient 181, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 489
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 201
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/201
# 282
# 282
# []
# WARNING! The filter of the sequence at patient 201, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["13"]
# ["12"]
# ["14"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 531
# number of failures occured during processing.E.g. file does not have metaheader: 7
# processing study: 3
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/3
# 272
# 272
# []
# WARNING! The filter of the sequence at patient 3, in dose 100 has been lowered
# Sequences before
# []
# []
# []
# Sequences after
# ["10"]
# ["9"]
# ["11"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 641
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 50
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/50
# 332
# 332
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# ...
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 228
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/228
# 335
# 335
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1479
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 229
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/229
# 259
# 259
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 525
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 23
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/23
# 380
# 380
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1798
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 230
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/230
# 326
# 326
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1578
# number of failures occured during processing.E.g. file does not have metaheader: 1238
# processing study: 24
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/24
# 315
# 315
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 2454
# number of failures occured during processing.E.g. file does not have metaheader: 8
# processing study: 25
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/25
# 304
# 304
# []
# Sequences before
# []
# []
# []
# Sequences after
# ["7"]
# ["6"]
# ["5", "8"]
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 0
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 26
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/26
# 338
# 338
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# number of files that has not bee copied: 1352
# number of failures occured during processing.E.g. file does not have metaheader: 2
# processing study: 27
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/27
# 331
# 331
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1476
# number of failures occured during processing.E.g. file does not have metaheader: 5
# processing study: 28
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/28
# 347
# 347
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1388
# number of failures occured during processing.E.g. file does not have metaheader: 6
# processing study: 29
# /media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/29
# 342
# 342
# []
# Sequences before
# []
# []
# []
# Sequences after
# []
# []
# []
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# Failure B
# number of files that has not bee copied: 1916
# number of failures occured during processing.E.g. file does not have metaheader: 7

# %%
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 214
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75432.30000020061807274821200005896
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.30071.8
# (0002, 0013) Implementation Version Name         SH: 'SmartAnonymize'
# (0002, 0016) Source Application Entity Title     AE: 'EE2001664RADQR'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI DUAL', 'STD', 'DNRG', 'DET_A']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.75432.30000020061807274821200005896
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Force'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6351480
#    ---------
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.1.1.10.139.16.103.20200628185742895.48210
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061801162848700000488
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061807163540600000019
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.75432.30000020061807163540600000019
# (0010, 0010) Patient's Name                      PN: '109'
# (0010, 0020) Patient ID                          LO: '109'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0018, 0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018, 0050) Slice Thickness                     DS: "1.0"
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1020) Software Versions                   LO: 'syngo CT VB20A'
# (0018, 1100) Reconstruction Diameter             DS: "334.0"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "134.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "98"
# (0018, 1152) Exposure                            IS: "40"
# (0018, 1160) Filter Type                         SH: 'FLAT'
# (0018, 1170) Generator Power                     IS: "9"
# (0018, 1190) Focal Spot(s)                       DS: "0.8"
# (0018, 1200) Date of Last Calibration            DA: '20200618'
# (0018, 1201) Time of Last Calibration            TM: '022444.000000'
# (0018, 1210) Convolution Kernel                  SH: ['Bl64d', '3']
# (0018, 5100) Patient Position                    CS: 'FFP'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 92.0
# (0018, 9310) Table Feed per Rotation             FD: 46.0
# (0018, 9311) Spiral Pitch Factor                 FD: 1.2
# (0018, 9313) Data Collection Center (Patient)    FD: [0.0, 134.5, -360.2]
# (0018, 9318) Reconstruction Target Center (Patie FD: [-2.0, 153.5, -360.2]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 55.277
# (0018, 9345) CTDIvol                             FD: 1.743572368695652
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6351480
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.75432.30000020061801162848700000567
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "6"
# (0020, 0012) Acquisition Number                  IS: "3"
# (0020, 0013) Instance Number                     IS: "39"
# (0020, 0032) Image Position (Patient)            DS: [-168.673828125, -13.173828125, -360.2]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.75432.30000020061807163540600000016
# (0020, 0060) Laterality                          CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "360.2"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.65234375, 0.65234375]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 3353
# (0028, 1050) Window Center                       DS: [-600, 50]
# (0028, 1051) Window Width                        DS: [1200, 350]
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0032, 000a) Study Status ID                     CS: 'R'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (7fe0, 0010) Pixel Data                          OB: Array of 328470 elements

# %%
ds.ImageType[6] == "DET_A" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series66
# Out:
# True

# %%
if ds.ImageType[6] == "DET_A" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series33 :
    path_det_a = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber), i_file)
    seq_dir = os.path.join(output_dir, i_dir, "66", str(ds.SeriesNumber))
    if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
    if not os.path.isfile(path_det_a): copy_dcm_file(source = path_i_file, destination = path_det_a)

elif ds.ImageType[6] == "DET_B" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series66:
    path_det_b = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber), i_file)
    seq_dir = os.path.join(output_dir, i_dir, "33", str(ds.SeriesNumber))
    if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
    if not os.path.isfile(path_det_b): copy_dcm_file(source = path_i_file, destination = path_det_b)

elif ds.ImageType[6] == "DET_AB" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series100:
    seq_dir = os.path.join(output_dir, i_dir, "100", str(ds.SeriesNumber))
    if not os.path.isdir(seq_dir): os.mkdir(seq_dir)
    path_det_ab = os.path.join(output_dir, i_dir, "100",str(ds.SeriesNumber), i_file)
    if not os.path.isfile(path_det_ab): copy_dcm_file(source = path_i_file, destination = path_det_ab)
else:
    counter +=1

# %%
len({max_slice_33, max_slice_66, max_slice_100}) == 1
# Out:
# True

# %%
ds.SeriesNumber
# Out:
# "7"

# %%
max_series100
# Out:
# ["8"]

# %%
max_series100 += [ds.SeriesNumber]

# %%
max_series100.remove(ds.SeriesNumber)

# %%
if len({max_slice_33, max_slice_66, max_slice_100}) is False:
    min_slice_threshold = min(max_slice_33, max_slice_66, max_slice_100)
    if max_slice_33 != min_slice_threshold:       
        max_slice_33 = min_slice_threshold
        print("WARNING! The filter of the sequence at patient %i_dir, in dose 33 has been lowered")
    if max_slice_66 != min_slice_threshold:       
        max_slice_66 = min_slice_threshold
        print("WARNING! The filter of the sequence at patient %i_dir, in dose 66 has been lowered")
    if max_slice_100 != min_slice_threshold:       
        max_slice_100 = min_slice_threshold
        print("WARNING! The filter of the sequence at patient %i_dir, in dose 100 has been lowered")

# %%
len({max_slice_33, max_slice_66, max_slice_100})==1:
    
    print("k")

# %%
max_slice_33, max_slice_66, max_slice_100
len({max_slice_33, max_slice_66, max_slice_100})

# %%
len({max_slice_33, max_slice_66, max_slice_100})
# Out:
# 2

# %%
if max_slice_100 != min_slice_threshold:       
    max_slice_100 = min_slice_threshold

# %%
max_slice_66
# Out:
# "287"

# %%
max_slice_100 =326

# %%
max_slice_100
# Out:
# "287"

# %%
print(max_slice_33, max_slice_66, max_slice_100)
# Out:
# 287 287 302

# %%
ds.ImageType[6] == "DET_AB" and ds.ImageType[0] == "ORIGINAL" and ds.SeriesNumber in max_series100
path_det_ab
# Out:
# '/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split/10/100/15/1.3.12.2.1107.5.1.4.75432.30000020041606585187500017536.dcm'

# %%
ds.ImageType[6] == "DET_AB" and ds.ImageType[0] == "ORIGINAL"
# Out:
# True

# %%
max_series100 = []
max_series100 += [ds.SeriesNumber]
if ds.SeriesNumber not in max_series100: max_series100 += [ds.SeriesNumber]
max_series100
# Out:
# ["15"]

# %%
k = []
k+= ds.SeriesNumber
k
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-184-fe5ee1389461> in <module>
#       1 k = []
# ----> 2 k+= ds.SeriesNumber
#       3 k
#
# TypeError: 'IS' object is not iterable

# %%
k=list()

# %%
k = k.append(str(ds.SeriesNumber))
print(k)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-175-681e9ff9da74> in <module>
# ----> 1 k = k.append(str(ds.SeriesNumber))
#       2 print(k)
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
a, b, c = 3, 3, 3
max_slice_33
# Out:
# True

# %%
ds = dicom.read_file(os.path.join(path_in_patient, i_file))
ds.ImageType[6] == "DET_AB"
# Out:
# True

# %%
path_det_ab = os.path.join(output_dir, i_dir, "100")
if not os.path.isdir(path_det_ab): os.mkdir(path_det_ab)
copy_dcm_file(source = path_i_file, destination = path_det_ab)
# Out:
# Error occurred while copying file.

# %%
path_i_file
# Out:
# '/media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/1/1.3.12.2.1107.5.1.4.75432.30000020061507080076200016909.dcm'

# %%
path_det_ab
# Out:
# '/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split/1/100'

# %%
path_det_b
# Out:
# '/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split/1/33'

# %%
filename = "1.3.12.2.1107.5.1.4.75432.30000020061507080076200016414.dcm"
path_file = os.path.join("/media/nraresearch/Elements/Dual_Split_Projekt_ETH/Anonmyized_final_dual_split/1", filename)

ds = dicom.read_file(path_file)

# %%
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 214
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75432.30000020061507080076200016414
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.30071.8
# (0002, 0013) Implementation Version Name         SH: 'SmartAnonymize'
# (0002, 0016) Source Application Entity Title     AE: 'EE2001664RADQR'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI DUAL', 'STD', 'DNRG', 'DET_AB']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.75432.30000020061507080076200016414
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Force'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
#    ---------
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.1.1.10.139.16.103.20200627184215621.55852
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061502465079700002206
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000086
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000086
# (0010, 0010) Patient's Name                      PN: '1'
# (0010, 0020) Patient ID                          LO: '1'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0018, 0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018, 0050) Slice Thickness                     DS: "1.5"
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1020) Software Versions                   LO: 'syngo CT VB20A'
# (0018, 1100) Reconstruction Diameter             DS: "420.0"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "201.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "121"
# (0018, 1152) Exposure                            IS: "50"
# (0018, 1160) Filter Type                         SH: 'FLAT'
# (0018, 1170) Generator Power                     IS: "15"
# (0018, 1190) Focal Spot(s)                       DS: "0.8"
# (0018, 1200) Date of Last Calibration            DA: '20200615'
# (0018, 1201) Time of Last Calibration            TM: '035510.000000'
# (0018, 1210) Convolution Kernel                  SH: ['Bl64d', '3']
# (0018, 5100) Patient Position                    CS: 'FFP'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 92.0
# (0018, 9310) Table Feed per Rotation             FD: 46.0
# (0018, 9311) Spiral Pitch Factor                 FD: 1.2
# (0018, 9313) Data Collection Center (Patient)    FD: [0.0, 201.5, -596.8]
# (0018, 9318) Reconstruction Target Center (Patie FD: [5.0, 168.5, -596.8]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 52.7561
# (0018, 9345) CTDIvol                             FD: 2.152778128695652
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0018, 9353) Energy Weighting Factor             FL: 0.6000000238418579
# (0018, 9360)  CT Additional X-Ray Source Sequence  1 item(s) ----
#    (0018, 0060) KVP                                 DS: "100.0"
#    (0018, 0090) Data Collection Diameter            DS: "0.0"
#    (0018, 1160) Filter Type                         SH: 'FLAT'
#    (0018, 1190) Focal Spot(s)                       DS: "0.8"
#    (0018, 7050) Filter Material                     CS: 'TITANIUM'
#    (0018, 9330) X-Ray Tube Current in mA            FD: 62.0
#    (0018, 9332) Exposure in mAs                     FD: 25.0
#    (0018, 9353) Energy Weighting Factor             FL: 0.4000000059604645
#    ---------
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.75432.30000020061507080076200016199
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "8"
# (0020, 0012) Acquisition Number                  IS: "3"
# (0020, 0013) Instance Number                     IS: "215"
# (0020, 0032) Image Position (Patient)            DS: [-204.58984375, -41.08984375, -596.8]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000081
# (0020, 0060) Laterality                          CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "596.8"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.8203125, 0.8203125]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 3487
# (0028, 1050) Window Center                       DS: [-600, 50]
# (0028, 1051) Window Width                        DS: [1200, 350]
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0032, 000a) Study Status ID                     CS: 'R'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (6000, 0010) Overlay Rows                        US: 512
# (6000, 0011) Overlay Columns                     US: 512
# (6000, 0015) Number of Frames in Overlay         IS: "1"
# (6000, 0022) Overlay Description                 LO: 'Siemens MedCom Object Graphics'
# (6000, 0040) Overlay Type                        CS: 'G'
# (6000, 0050) Overlay Origin                      SS: [1, 1]
# (6000, 0051) Image Frame Origin                  US: 1
# (6000, 0100) Overlay Bits Allocated              US: 1
# (6000, 0102) Overlay Bit Position                US: 0
# (7fe0, 0010) Pixel Data                          OB: Array of 297434 elements

# %%
ds.ImageType[6]
# Out:
# 'DET_AB'

# %%
filename = "1.3.12.2.1107.5.1.4.75432.30000020061507080076200015958.dcm"
path_file = os.path.join("/media/nraresearch/Elements/Dual_Split_Test_For_Bence/33%/PP Lunge Inspi 1.5  Bl64  3 LCAD  B_100kV", filename)

ds = dicom.read_file(path_file)
# 33%
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 212
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75432.30000020061507080076200015958
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.30071.8
# (0002, 0013) Implementation Version Name         SH: 'fo-dicom 4.0.4'
# (0002, 0016) Source Application Entity Title     AE: 'SYNEDRA_AIM'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI DUAL', 'STD', 'DNRG', 'DET_B']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.75432.30000020061507080076200015958
# (0008, 0020) Study Date                          DA: '20200615'
# (0008, 0021) Series Date                         DA: '20200615'
# (0008, 0022) Acquisition Date                    DA: '20200615'
# (0008, 0023) Content Date                        DA: '20200615'
# (0008, 002a) Acquisition DateTime                DT: '20200615102647.828000'
# (0008, 0030) Study Time                          TM: '102419.757000'
# (0008, 0031) Series Time                         TM: '102744.639000'
# (0008, 0032) Acquisition Time                    TM: '102647.828000'
# (0008, 0033) Content Time                        TM: '102647.828000'
# (0008, 0050) Accession Number                    SH: '5838155'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'Radiologie USZ'
# (0008, 0081) Institution Address                 ST: 'Raemistrasse\r\nZuerich\r\nZuerich\r\nCHE'
# (0008, 0090) Referring Physician's Name          PN: '6602'
# (0008, 1010) Station Name                        SH: 'CTAWP75432'
# (0008, 1030) Study Description                   LO: 'CT Thorax'
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0008, 103e) Series Description                  LO: 'PP Lunge Inspi 1.5  Bl64  3 LCAD  B_100kV'
# (0008, 1040) Institutional Department Name       LO: 'DEFAULT'
# (0008, 1048) Physician(s) of Record              PN: '6602'
# (0008, 1050) Performing Physician's Name         PN: '^'
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Force'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
#    ---------
# (0008, 1120)  Referenced Patient Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Patient Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.276.0.14.200.24.14.432928
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061502465079700002206
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000086
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000086
# (0009, 0010) Private Creator                     LO: 'SIEMENS CT VA1 DUMMY'
# (0010, 0010) Patient's Name                      PN: 'KRASNIQI^NURIJE'
# (0010, 0020) Patient ID                          LO: '06441742'
# (0010, 0030) Patient's Birth Date                DA: '19510101'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '069Y'
# (0010, 1020) Patient's Size                      DS: "0.92"
# (0010, 1030) Patient's Weight                    DS: "89.0"
# (0010, 21b0) Additional Patient History          LT: 'CT in In/Expiration, Frage nach Air-Trapping'
# (0010, 21c0) Pregnancy Status                    US: 4
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0050) Slice Thickness                     DS: "1.5"
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 0090) Data Collection Diameter            DS: "0.0"
# (0018, 1000) Device Serial Number                LO: '75432'
# (0018, 1020) Software Versions                   LO: 'syngo CT VB20A'
# (0018, 1030) Protocol Name                       LO: 'C_THINEX'
# (0018, 1100) Reconstruction Diameter             DS: "420.0"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "201.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "50"
# (0018, 1152) Exposure                            IS: "20"
# (0018, 1160) Filter Type                         SH: 'FLAT'
# (0018, 1170) Generator Power                     IS: "7"
# (0018, 1190) Focal Spot(s)                       DS: "0.8"
# (0018, 1200) Date of Last Calibration            DA: '20200615'
# (0018, 1201) Time of Last Calibration            TM: '035510.000000'
# (0018, 1210) Convolution Kernel                  SH: ['Bl64d', '3']
# (0018, 5100) Patient Position                    CS: 'FFP'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 92.0
# (0018, 9310) Table Feed per Rotation             FD: 46.0
# (0018, 9311) Spiral Pitch Factor                 FD: 1.2
# (0018, 9313) Data Collection Center (Patient)    FD: [0.0, 201.5, -457.8]
# (0018, 9318) Reconstruction Target Center (Patie FD: [5.0, 168.5, -457.8]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 52.7561
# (0018, 9345) CTDIvol                             FD: 0.8895777391304347
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0019, 0010) Private Creator                     LO: 'SIEMENS CT VA0  COAD'
# (0019, 1090) [Osteo Offset]                      DS: "0.0"
# (0019, 1092) [Osteo Regression Line Slope]       DS: "10000.0"
# (0019, 1093) [Osteo Regression Line Intercept]   DS: "10000.0"
# (0019, 1096) [Osteo Phantom Number]              IS: "0"
# (0019, 10b0) [Feed per Rotation]                 DS: "46.0"
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.75432.30000020061502465079700002281
# (0020, 0010) Study ID                            SH: '5838155'
# (0020, 0011) Series Number                       IS: "7"
# (0020, 0012) Acquisition Number                  IS: "3"
# (0020, 0013) Instance Number                     IS: "76"
# (0020, 0032) Image Position (Patient)            DS: [-204.58984375, -41.08984375, -457.8]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000081
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "457.8"
# (0020, 4000) Image Comments                      LT: ''
# (0021, 0010) Private Creator                     LO: 'SIEMENS MED'
# (0021, 1011) [Target]                            DS: [5, 33]
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.8203125, 0.8203125]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 4095
# (0028, 1050) Window Center                       DS: [-600, 50]
# (0028, 1051) Window Width                        DS: [1200, 350]
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'MITRA PRESENTATION 1.0'
# (0029, 1008) [CSA Image Header Type]             CS: 'SOM 5'
# (0029, 1009) [CSA Image Header Version]          LO: 'VA10A 971201'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 1424 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'SOM 7 DEV'
# (0029, 1019) [CSA Series Header Version]         LO: 'VA11A_20060321'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 142 elements
# (0029, 1140)  [Application Header Sequence]  3 item(s) ----
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'VIA_CARE_KV_WIND'
#    (0029, 1042) [Application Header ID]             LO: 'ORIG WINDOW VALUES FROM CAREKV'
#    (0029, 1043) [Application Header Version]        LO: 'V1 20120914'
#    (0029, 1044) [Application Header Info]           OB: Array of 20 elements
#    ---------
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'SOM 5 TPOS'
#    (0029, 1042) [Application Header ID]             LO: 'SOM 5 NULLPOSITION'
#    (0029, 1043) [Application Header Version]        LO: 'VB10A 20030626'
#    (0029, 1044) [Application Header Info]           OB: b'-000022325\x00\x05'
#    ---------
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'SOM 7 DEV'
#    (0029, 1042) [Application Header ID]             LO: 'SOM 7 DUAL ENERGY'
#    (0029, 1043) [Application Header Version]        LO: 'VA50A 20130805'
#    (0029, 1044) [Application Header Info]           OB: Array of 68 elements
#    ---------
# (0029, 1210) Private tag data                    CS: '-2'
# (0029, 1211) Private tag data                    CS: '-2'
# (0029, 1212) Private tag data                    CS: '-2'
# (0029, 1213) Private tag data                    CS: '-2'
# (0031, 0010) Private Creator                     LO: 'AGFA PACS Archive Mirroring 1.0'
# (0031, 1000) [Unknown]                           CS: 'N'
# (0031, 1001) [Unknown]                           UL: 1592209186
# (0032, 000a) Study Status ID                     CS: 'COMPLETED'
# (0032, 1030) Reason for Study                    LO: 'CT in In/Expiration, Frage nach Air-Trapping'
# (0032, 1032) Requesting Physician                PN: '6602'
# (0032, 1033) Requesting Service                  LO: 'PNE ambulant RAE'
# (0032, 1060) Requested Procedure Description     LO: 'CT Thorax'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0032, 4000) Study Comments                      LT: '5838155'
# (0033, 0010) Private Creator                     LO: 'MITRA OBJECT UTF8 ATTRIBUTES 1.0'
# (0033, 1004) [Study Description]                 CS: 'CT Thorax'
# (0033, 100c) [Reason for Study]                  LO: 'CT in In/Expiration, Frage nach Air-Trapping'
# (0033, 100e) [Unknown]                           LT: '5838155'
# (0033, 1013) [Patient's Name]                    PN: 'Krasniqi^Nurije^^'
# (0033, 1016) [Unknown]                           PN: '6602'
# (0033, 1019) [Referring Physician's Name]        PN: '6602'
# (0040, 0244) Performed Procedure Step Start Date DA: '20200615'
# (0040, 0245) Performed Procedure Step Start Time TM: '102419.757000'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0008, 0050) Accession Number                    SH: '5838155'
#    (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
#       ---------
#    (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
#    (0032, 1060) Requested Procedure Description     LO: 'CT Thorax'
#    (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'CTTH'
#       (0008, 0102) Coding Scheme Designator            SH: 'RP'
#       (0008, 0103) Coding Scheme Version               SH: ''
#       (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '5838155'
#    (0040, 1001) Requested Procedure ID              SH: '5838155'
#    ---------
# (0040, 1001) Requested Procedure ID              SH: '5838155'
# (7fe0, 0010) Pixel Data                          OB: Array of 212848 elements

# %%
ds.ImageType[6]
# Out:
# 'DET_B'

# %%
filename = "1.3.12.2.1107.5.1.4.75432.30000020061507080076200015587.dcm"
path_file = os.path.join("/media/nraresearch/Elements/Dual_Split_Test_For_Bence/66%/PP Lunge Inspi 1.5  Bl64  3 LCAD  A_100kV", filename)

ds = dicom.read_file(path_file)
# 66% det_A
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 212
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75432.30000020061507080076200015587
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.30071.8
# (0002, 0013) Implementation Version Name         SH: 'fo-dicom 4.0.4'
# (0002, 0016) Source Application Entity Title     AE: 'SYNEDRA_AIM'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI DUAL', 'STD', 'DNRG', 'DET_A']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.75432.30000020061507080076200015587
# (0008, 0020) Study Date                          DA: '20200615'
# (0008, 0021) Series Date                         DA: '20200615'
# (0008, 0022) Acquisition Date                    DA: '20200615'
# (0008, 0023) Content Date                        DA: '20200615'
# (0008, 002a) Acquisition DateTime                DT: '20200615102647.223000'
# (0008, 0030) Study Time                          TM: '102419.757000'
# (0008, 0031) Series Time                         TM: '102744.555000'
# (0008, 0032) Acquisition Time                    TM: '102647.223000'
# (0008, 0033) Content Time                        TM: '102647.223000'
# (0008, 0050) Accession Number                    SH: '5838155'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0080) Institution Name                    LO: 'Radiologie USZ'
# (0008, 0081) Institution Address                 ST: 'Raemistrasse\r\nZuerich\r\nZuerich\r\nCHE'
# (0008, 0090) Referring Physician's Name          PN: '6602'
# (0008, 1010) Station Name                        SH: 'CTAWP75432'
# (0008, 1030) Study Description                   LO: 'CT Thorax'
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0008, 103e) Series Description                  LO: 'PP Lunge Inspi 1.5  Bl64  3 LCAD  A_100kV'
# (0008, 1040) Institutional Department Name       LO: 'DEFAULT'
# (0008, 1048) Physician(s) of Record              PN: '6602'
# (0008, 1050) Performing Physician's Name         PN: '^'
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Force'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
#    ---------
# (0008, 1120)  Referenced Patient Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Patient Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.276.0.14.200.24.14.432928
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061502465079700002206
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000086
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000086
# (0009, 0010) Private Creator                     LO: 'SIEMENS CT VA1 DUMMY'
# (0010, 0010) Patient's Name                      PN: 'KRASNIQI^NURIJE'
# (0010, 0020) Patient ID                          LO: '06441742'
# (0010, 0030) Patient's Birth Date                DA: '19510101'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '069Y'
# (0010, 1020) Patient's Size                      DS: "0.92"
# (0010, 1030) Patient's Weight                    DS: "89.0"
# (0010, 21b0) Additional Patient History          LT: 'CT in In/Expiration, Frage nach Air-Trapping'
# (0010, 21c0) Pregnancy Status                    US: 4
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0050) Slice Thickness                     DS: "1.5"
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1000) Device Serial Number                LO: '75432'
# (0018, 1020) Software Versions                   LO: 'syngo CT VB20A'
# (0018, 1030) Protocol Name                       LO: 'C_THINEX'
# (0018, 1100) Reconstruction Diameter             DS: "420.0"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "201.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "130"
# (0018, 1152) Exposure                            IS: "54"
# (0018, 1160) Filter Type                         SH: 'FLAT'
# (0018, 1170) Generator Power                     IS: "15"
# (0018, 1190) Focal Spot(s)                       DS: "0.8"
# (0018, 1200) Date of Last Calibration            DA: '20200615'
# (0018, 1201) Time of Last Calibration            TM: '035510.000000'
# (0018, 1210) Convolution Kernel                  SH: ['Bl64d', '3']
# (0018, 5100) Patient Position                    CS: 'FFP'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 92.0
# (0018, 9310) Table Feed per Rotation             FD: 46.0
# (0018, 9311) Spiral Pitch Factor                 FD: 1.2
# (0018, 9313) Data Collection Center (Patient)    FD: [0.0, 201.5, -401.8]
# (0018, 9318) Reconstruction Target Center (Patie FD: [5.0, 168.5, -401.8]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 52.7561
# (0018, 9345) CTDIvol                             FD: 2.3129021217391306
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0019, 0010) Private Creator                     LO: 'SIEMENS CT VA0  COAD'
# (0019, 1090) [Osteo Offset]                      DS: "0.0"
# (0019, 1092) [Osteo Regression Line Slope]       DS: "10000.0"
# (0019, 1093) [Osteo Regression Line Intercept]   DS: "10000.0"
# (0019, 1096) [Osteo Phantom Number]              IS: "0"
# (0019, 10b0) [Feed per Rotation]                 DS: "46.0"
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.75432.30000020061502465079700002280
# (0020, 0010) Study ID                            SH: '5838155'
# (0020, 0011) Series Number                       IS: "6"
# (0020, 0012) Acquisition Number                  IS: "3"
# (0020, 0013) Instance Number                     IS: "20"
# (0020, 0032) Image Position (Patient)            DS: [-204.58984375, -41.08984375, -401.8]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.75432.30000020061506584828300000081
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "401.8"
# (0020, 4000) Image Comments                      LT: ''
# (0021, 0010) Private Creator                     LO: 'SIEMENS MED'
# (0021, 1011) [Target]                            DS: [5, 33]
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.8203125, 0.8203125]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 4095
# (0028, 1050) Window Center                       DS: [-600, 50]
# (0028, 1051) Window Width                        DS: [1200, 350]
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0029, 0010) Private Creator                     LO: 'SIEMENS CSA HEADER'
# (0029, 0011) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
# (0029, 0012) Private Creator                     LO: 'MITRA PRESENTATION 1.0'
# (0029, 1008) [CSA Image Header Type]             CS: 'SOM 5'
# (0029, 1009) [CSA Image Header Version]          LO: 'VA10A 971201'
# (0029, 1010) [CSA Image Header Info]             OB: Array of 1424 elements
# (0029, 1018) [CSA Series Header Type]            CS: 'SOM 7 DEV'
# (0029, 1019) [CSA Series Header Version]         LO: 'VA11A_20060321'
# (0029, 1020) [CSA Series Header Info]            OB: Array of 142 elements
# (0029, 1140)  [Application Header Sequence]  3 item(s) ----
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'VIA_CARE_KV_WIND'
#    (0029, 1042) [Application Header ID]             LO: 'ORIG WINDOW VALUES FROM CAREKV'
#    (0029, 1043) [Application Header Version]        LO: 'V1 20120914'
#    (0029, 1044) [Application Header Info]           OB: Array of 20 elements
#    ---------
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'SOM 5 TPOS'
#    (0029, 1042) [Application Header ID]             LO: 'SOM 5 NULLPOSITION'
#    (0029, 1043) [Application Header Version]        LO: 'VB10A 20030626'
#    (0029, 1044) [Application Header Info]           OB: b'-000022325\x00\x02'
#    ---------
#    (0029, 0010) Private Creator                     LO: 'SIEMENS MEDCOM HEADER'
#    (0029, 1041) [Application Header Type]           CS: 'SOM 7 DEV'
#    (0029, 1042) [Application Header ID]             LO: 'SOM 7 DUAL ENERGY'
#    (0029, 1043) [Application Header Version]        LO: 'VA50A 20130805'
#    (0029, 1044) [Application Header Info]           OB: Array of 68 elements
#    ---------
# (0029, 1210) Private tag data                    CS: '-2'
# (0029, 1211) Private tag data                    CS: '-2'
# (0029, 1212) Private tag data                    CS: '-2'
# (0029, 1213) Private tag data                    CS: '-2'
# (0031, 0010) Private Creator                     LO: 'AGFA PACS Archive Mirroring 1.0'
# (0031, 1000) [Unknown]                           CS: 'N'
# (0031, 1001) [Unknown]                           UL: 1592209186
# (0032, 000a) Study Status ID                     CS: 'COMPLETED'
# (0032, 1030) Reason for Study                    LO: 'CT in In/Expiration, Frage nach Air-Trapping'
# (0032, 1032) Requesting Physician                PN: '6602'
# (0032, 1033) Requesting Service                  LO: 'PNE ambulant RAE'
# (0032, 1060) Requested Procedure Description     LO: 'CT Thorax'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0032, 4000) Study Comments                      LT: '5838155'
# (0033, 0010) Private Creator                     LO: 'MITRA OBJECT UTF8 ATTRIBUTES 1.0'
# (0033, 1004) [Study Description]                 CS: 'CT Thorax'
# (0033, 100c) [Reason for Study]                  LO: 'CT in In/Expiration, Frage nach Air-Trapping'
# (0033, 100e) [Unknown]                           LT: '5838155'
# (0033, 1013) [Patient's Name]                    PN: 'Krasniqi^Nurije^^'
# (0033, 1016) [Unknown]                           PN: '6602'
# (0033, 1019) [Referring Physician's Name]        PN: '6602'
# (0040, 0244) Performed Procedure Step Start Date DA: '20200615'
# (0040, 0245) Performed Procedure Step Start Time TM: '102419.757000'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0008, 0050) Accession Number                    SH: '5838155'
#    (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#       (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
#       ---------
#    (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.5838155
#    (0032, 1060) Requested Procedure Description     LO: 'CT Thorax'
#    (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'CTTH'
#       (0008, 0102) Coding Scheme Designator            SH: 'RP'
#       (0008, 0103) Coding Scheme Version               SH: ''
#       (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#       ---------
#    (0040, 0009) Scheduled Procedure Step ID         SH: '5838155'
#    (0040, 1001) Requested Procedure ID              SH: '5838155'
#    ---------
# (0040, 1001) Requested Procedure ID              SH: '5838155'
# (7fe0, 0010) Pixel Data                          OB: Array of 302116 elements

# %%
ds.ImageType[6]
# Out:
# 'DET_A'

# %%
# d 100 series 15 - should keep
filename = "1.3.12.2.1107.5.1.4.75432.30000020041606585187500017377.dcm"
path_file = os.path.join("/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split/10/100", filename)
ds = dicom.read_file(path_file)
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 214
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500017377
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.30071.8
# (0002, 0013) Implementation Version Name         SH: 'SmartAnonymize'
# (0002, 0016) Source Application Entity Title     AE: 'EE2001664RADQR'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI DUAL', 'STD', 'DNRG', 'DET_AB']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500017377
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Force'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6254813
#    ---------
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.1.1.10.139.16.103.20200618174634146.49487
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020041602275452200000571
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000036
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000036
# (0010, 0010) Patient's Name                      PN: '10'
# (0010, 0020) Patient ID                          LO: '10'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0018, 0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018, 0050) Slice Thickness                     DS: "1.5"
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1020) Software Versions                   LO: 'syngo CT VB20A'
# (0018, 1100) Reconstruction Diameter             DS: "409.0"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "175.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "125"
# (0018, 1152) Exposure                            IS: "52"
# (0018, 1160) Filter Type                         SH: 'FLAT'
# (0018, 1170) Generator Power                     IS: "19"
# (0018, 1190) Focal Spot(s)                       DS: "0.8"
# (0018, 1200) Date of Last Calibration            DA: '20200416'
# (0018, 1201) Time of Last Calibration            TM: '033712.000000'
# (0018, 1210) Convolution Kernel                  SH: ['Bl64d', '3']
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 92.0
# (0018, 9310) Table Feed per Rotation             FD: 46.0
# (0018, 9311) Spiral Pitch Factor                 FD: 1.2
# (0018, 9313) Data Collection Center (Patient)    FD: [0.0, -175.5, 855.4]
# (0018, 9318) Reconstruction Target Center (Patie FD: [9.0, -175.5, 855.4]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 72.6438
# (0018, 9345) CTDIvol                             FD: 2.223944347826087
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0018, 9353) Energy Weighting Factor             FL: 0.6000000238418579
# (0018, 9360)  CT Additional X-Ray Source Sequence  1 item(s) ----
#    (0018, 0060) KVP                                 DS: "100.0"
#    (0018, 0090) Data Collection Diameter            DS: "0.0"
#    (0018, 1160) Filter Type                         SH: 'FLAT'
#    (0018, 1190) Focal Spot(s)                       DS: "0.8"
#    (0018, 7050) Filter Material                     CS: 'TITANIUM'
#    (0018, 9330) X-Ray Tube Current in mA            FD: 62.0
#    (0018, 9332) Exposure in mAs                     FD: 25.0
#    (0018, 9353) Energy Weighting Factor             FL: 0.4000000059604645
#    ---------
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6254813
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500017197
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "15"
# (0020, 0012) Acquisition Number                  IS: "4"
# (0020, 0013) Instance Number                     IS: "180"
# (0020, 0032) Image Position (Patient)            DS: [-195.1005859375, -379.6005859375, 855.4]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000032
# (0020, 0060) Laterality                          CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-855.4"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.798828125, 0.798828125]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 3050
# (0028, 1050) Window Center                       DS: [-600, 50]
# (0028, 1051) Window Width                        DS: [1200, 350]
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0032, 000a) Study Status ID                     CS: 'R'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (6000, 0010) Overlay Rows                        US: 512
# (6000, 0011) Overlay Columns                     US: 512
# (6000, 0015) Number of Frames in Overlay         IS: "1"
# (6000, 0022) Overlay Description                 LO: 'Siemens MedCom Object Graphics'
# (6000, 0040) Overlay Type                        CS: 'G'
# (6000, 0050) Overlay Origin                      SS: [1, 1]
# (6000, 0051) Image Frame Origin                  US: 1
# (6000, 0100) Overlay Bits Allocated              US: 1
# (6000, 0102) Overlay Bit Position                US: 0
# (7fe0, 0010) Pixel Data                          OB: Array of 307446 elements

# %%
# patient 10, d 100 series 7- should be dropped out
filename = "1.3.12.2.1107.5.1.4.75432.30000020041606585187500010074.dcm"
path_file = os.path.join("/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split/10/100", filename)
ds = dicom.read_file(path_file)
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 214
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500010074
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.30071.8
# (0002, 0013) Implementation Version Name         SH: 'SmartAnonymize'
# (0002, 0016) Source Application Entity Title     AE: 'EE2001664RADQR'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI DUAL', 'STD', 'DNRG', 'DET_AB']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500010074
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Force'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6254813
#    ---------
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.1.1.10.139.16.103.20200618174634146.12163
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020041602275452200000571
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000036
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000036
# (0010, 0010) Patient's Name                      PN: '10'
# (0010, 0020) Patient ID                          LO: '10'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0018, 0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018, 0050) Slice Thickness                     DS: "2.0"
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1020) Software Versions                   LO: 'syngo CT VB20A'
# (0018, 1100) Reconstruction Diameter             DS: "409.0"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "175.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "500"
# (0018, 1151) X-Ray Tube Current                  IS: "161"
# (0018, 1152) Exposure                            IS: "67"
# (0018, 1160) Filter Type                         SH: 'FLAT'
# (0018, 1170) Generator Power                     IS: "19"
# (0018, 1190) Focal Spot(s)                       DS: "0.8"
# (0018, 1200) Date of Last Calibration            DA: '20200416'
# (0018, 1201) Time of Last Calibration            TM: '033712.000000'
# (0018, 1210) Convolution Kernel                  SH: ['Br36d', '3']
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 92.0
# (0018, 9310) Table Feed per Rotation             FD: 46.0
# (0018, 9311) Spiral Pitch Factor                 FD: 1.2
# (0018, 9313) Data Collection Center (Patient)    FD: [0.0, -175.5, 724.0]
# (0018, 9318) Reconstruction Target Center (Patie FD: [9.0, -175.5, 724.0]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 72.6438
# (0018, 9345) CTDIvol                             FD: 2.86444032
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0018, 9353) Energy Weighting Factor             FL: 0.6000000238418579
# (0018, 9360)  CT Additional X-Ray Source Sequence  1 item(s) ----
#    (0018, 0060) KVP                                 DS: "100.0"
#    (0018, 0090) Data Collection Diameter            DS: "0.0"
#    (0018, 1160) Filter Type                         SH: 'FLAT'
#    (0018, 1190) Focal Spot(s)                       DS: "0.8"
#    (0018, 7050) Filter Material                     CS: 'TITANIUM'
#    (0018, 9330) X-Ray Tube Current in mA            FD: 83.0
#    (0018, 9332) Exposure in mAs                     FD: 34.0
#    (0018, 9353) Energy Weighting Factor             FL: 0.4000000059604645
#    ---------
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6254813
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500009879
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "7"
# (0020, 0012) Acquisition Number                  IS: "4"
# (0020, 0013) Instance Number                     IS: "195"
# (0020, 0032) Image Position (Patient)            DS: [-195.1005859375, -379.6005859375, 724]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000032
# (0020, 0060) Laterality                          CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-724.0"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.798828125, 0.798828125]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 2548
# (0028, 1050) Window Center                       DS: [50, -600]
# (0028, 1051) Window Width                        DS: [350, 1200]
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0032, 000a) Study Status ID                     CS: 'R'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (6000, 0010) Overlay Rows                        US: 512
# (6000, 0011) Overlay Columns                     US: 512
# (6000, 0015) Number of Frames in Overlay         IS: "1"
# (6000, 0022) Overlay Description                 LO: 'Siemens MedCom Object Graphics'
# (6000, 0040) Overlay Type                        CS: 'G'
# (6000, 0050) Overlay Origin                      SS: [1, 1]
# (6000, 0051) Image Frame Origin                  US: 1
# (6000, 0100) Overlay Bits Allocated              US: 1
# (6000, 0102) Overlay Bit Position                US: 0
# (7fe0, 0010) Pixel Data                          OB: Array of 215836 elements

# %%
# patient 10,  d100 series 7- should be dropped out
filename = "1.3.12.2.1107.5.1.4.75432.30000020041606585187500009439.dcm"
path_file = os.path.join("/media/nraresearch/Elements/Dual_Split_Projekt_ETH/preprocessed_dual_split/10/100", filename)
ds = dicom.read_file(path_file)
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 214
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500009439
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.30071.8
# (0002, 0013) Implementation Version Name         SH: 'SmartAnonymize'
# (0002, 0016) Source Application Entity Title     AE: 'EE2001664RADQR'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI DUAL', 'STD', 'SNRG', 'DET_AB']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500009439
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: ''
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (0008, 1090) Manufacturer's Model Name           LO: 'SOMATOM Force'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6254813
#    ---------
# (0008, 1111)  Referenced Performed Procedure Step Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Modality Performed Procedure Step SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.40.0.13.1.1.1.10.139.16.103.20200618174634146.12163
#    ---------
# (0008, 1140)  Referenced Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020041602275452200000571
#    ---------
# (0008, 2112)  Source Image Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: 1.3.12.2.1107.5.9.1
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000037
#    ---------
# (0008, 3010) Irradiation Event UID               UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000037
# (0010, 0010) Patient's Name                      PN: '10'
# (0010, 0020) Patient ID                          LO: '10'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0018, 0015) Body Part Examined                  CS: 'ABDOMEN'
# (0018, 0050) Slice Thickness                     DS: "2.0"
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 0090) Data Collection Diameter            DS: "500.0"
# (0018, 1020) Software Versions                   LO: 'syngo CT VB20A'
# (0018, 1100) Reconstruction Diameter             DS: "354.0"
# (0018, 1110) Distance Source to Detector         DS: "1085.6"
# (0018, 1111) Distance Source to Patient          DS: "595.0"
# (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
# (0018, 1130) Table Height                        DS: "175.5"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "250"
# (0018, 1151) X-Ray Tube Current                  IS: "856"
# (0018, 1152) Exposure                            IS: "70"
# (0018, 1160) Filter Type                         SH: 'WEDGE_2 SN_DE'
# (0018, 1170) Generator Power                     IS: "58"
# (0018, 1190) Focal Spot(s)                       DS: "0.8"
# (0018, 1200) Date of Last Calibration            DA: '20200416'
# (0018, 1201) Time of Last Calibration            TM: '033712.000000'
# (0018, 1210) Convolution Kernel                  SH: ['Bl64d', '5']
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 57.599999999999994
# (0018, 9309) Table Speed                         FD: 691.2
# (0018, 9310) Table Feed per Rotation             FD: 172.8
# (0018, 9311) Spiral Pitch Factor                 FD: 3.0
# (0018, 9313) Data Collection Center (Patient)    FD: [0.0, -175.5, 799.1]
# (0018, 9318) Reconstruction Target Center (Patie FD: [0.0, -175.5, 799.1]
# (0018, 9323) Exposure Modulation Type            CS: 'Z_EC'
# (0018, 9324) Estimated Dose Saving               FD: 51.5886
# (0018, 9345) CTDIvol                             FD: 0.2466920666666667
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113619.6.95.31.0.3.4.1.24.13.6254813
# (0020, 000e) Series Instance UID                 UI: 1.3.12.2.1107.5.1.4.75432.30000020041606585187500009299
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "4"
# (0020, 0012) Acquisition Number                  IS: "5"
# (0020, 0013) Instance Number                     IS: "140"
# (0020, 0032) Image Position (Patient)            DS: [-176.654296875, -352.154296875, 799.1]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.75432.30000020041607152495900000032
# (0020, 0060) Laterality                          CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-799.1"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.69140625, 0.69140625]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 3734
# (0028, 1050) Window Center                       DS: [-600, 50]
# (0028, 1051) Window Width                        DS: [1200, 350]
# (0028, 1052) Rescale Intercept                   DS: "-1024.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (0032, 000a) Study Status ID                     CS: 'R'
# (0032, 1064)  Requested Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'CTTH'
#    (0008, 0102) Coding Scheme Designator            SH: 'L'
#    (0008, 0104) Code Meaning                        LO: 'CT Thorax'
#    ---------
# (7fe0, 0010) Pixel Data                          OB: Array of 263776 elements
